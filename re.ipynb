# %%
import os


#file_path = './eye_data/new/'
file_path = './1014/res/5600/'
file_names = os.listdir(file_path)
#file_names

# %%
for name in file_names:
    src = os.path.join(file_path, name)
    dst=file_path+name[:-7]+".png"
    #dst=name.replace(" " , "")
    #dst=dst.replace("-" , "_")
    #dst = os.path.join(file_path, dst)
    print(name)
    print(dst)
    os.rename(src, dst)
# Out:
# 104_eyes_01.png
# ./1014/res/5600/104_eyes.png
# 107_eyes_01.png
# ./1014/res/5600/107_eyes.png
# 108_eyes_01.png
# ./1014/res/5600/108_eyes.png
# 109_eyes_01.png
# ./1014/res/5600/109_eyes.png
# 10_eyes_01.png
# ./1014/res/5600/10_eyes.png
# 110_eyes_01.png
# ./1014/res/5600/110_eyes.png
# 112_eyes_01.png
# ./1014/res/5600/112_eyes.png
# 115_eyes_01.png
# ./1014/res/5600/115_eyes.png
# 119_eyes_01.png
# ./1014/res/5600/119_eyes.png
# 11_eyes_01.png
# ./1014/res/5600/11_eyes.png
# 121_eyes_01.png
# ./1014/res/5600/121_eyes.png
# 122_eyes_01.png
# ./1014/res/5600/122_eyes.png
# 126_eyes_01.png
# ./1014/res/5600/126_eyes.png
# 127_eyes_01.png
# ./1014/res/5600/127_eyes.png
# 12_eyes_01.png
# ./1014/res/5600/12_eyes.png
# 130_eyes_01.png
# ./1014/res/5600/130_eyes.png
# 133_eyes_01.png
# ./1014/res/5600/133_eyes.png
# 136_eyes_01.png
# ./1014/res/5600/136_eyes.png
# 138_eyes_01.png
# ./1014/res/5600/138_eyes.png
# 13_eyes_01.png
# ./1014/res/5600/13_eyes.png
# 141_eyes_01.png
# ...

# %%
for name in file_names:
    src = os.path.join(file_path, name)
    dst=name.replace(" " , "")
    dst=dst.replace("-" , "_")
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)

# %%
import os
import natsort 
file_path = './09162/2/'
file_names = os.listdir(file_path)
file_names=natsort.natsorted(file_names,reverse=False)
file_names
num=1
for name in file_names:
    src = os.path.join(file_path, name)
#     dst=name.replace(" " , "")
#     dst=dst.replace("-" , "_")
#     dst = os.path.join(file_path, dst)
    os.rename(src, file_path+"/"+str(num)+".png")
    num=num+1

# %%
import os
file_path = './09162/6/'
file_names = os.listdir(file_path)
num=1
for name in file_names:
    src = os.path.join(file_path, name)
#     dst=name.replace(" " , "")
#     dst=dst.replace("-" , "_")
#     dst = os.path.join(file_path, dst)
    os.rename(src, file_path+"/"+str(num)+".png")
    num=num+1

# %%
num=1
for name in file_names:
    src = os.path.join(file_path, name)
    #dst=name.replace(" " , "")
    #dst = os.path.join(file_path, dst)
    os.rename(src, "./mydata/image/"+str(num)+".png")
    num=num+1
